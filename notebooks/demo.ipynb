# %%
# import relevant file paths into my notebook
import sys  
sys.path.append('C:/Users/coppe/OneDrive/Documents/GitHub/b1-coding-practical-mt24/uuv_mission')
sys.path.append('C:/Users/coppe/OneDrive/Documents/GitHub/b1-coding-practical-mt24/data/mission.csv')
print(sys.path)
# Out:
# ['c:\\Users\\coppe\\AppData\\Local\\Programs\\Python\\Python311\\python311.zip', 'c:\\Users\\coppe\\AppData\\Local\\Programs\\Python\\Python311\\Lib', 'c:\\Users\\coppe\\AppData\\Local\\Programs\\Python\\Python311\\DLLs', '', 'C:\\Users\\coppe\\AppData\\Roaming\\Python\\Python311\\site-packages', 'C:\\Users\\coppe\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32', 'C:\\Users\\coppe\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\coppe\\AppData\\Roaming\\Python\\Python311\\site-packages\\Pythonwin', 'c:\\Users\\coppe\\AppData\\Local\\Programs\\Python\\Python311', 'c:\\Users\\coppe\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages', 'C:/Users/coppe/OneDrive/Documents/GitHub/b1-coding-practical-mt24/uuv_mission', 'C:/Users/coppe/OneDrive/Documents/GitHub/b1-coding-practical-mt24/data/mission.csv']

# %% [markdown]
# # Simulate closed-loop
# After implementing your control functionality, you can simulate the closed-loop with code that looks something like this...

# %%
# Part 4: Testing with Jupyter

# Import relevant modules
import control
import dynamic

sub = dynamic.Submarine()

# Instantiate your controller
closed_loop = dynamic.ClosedLoop(sub, control.Controller(kp=0.1, kd=0.55))
mission = dynamic.Mission.from_csv("C:/Users/coppe/OneDrive/Documents/GitHub/b1-coding-practical-mt24/data/mission.csv")

trajectory = closed_loop.simulate_with_random_disturbances(mission)
trajectory.plot_completed_mission(mission)
